# %% [markdown]
# ## Q1) Write a python code snippet that prompts the user to enter their name and stores it in a variable and print a welcome message using the entered name.<a href="#Q1)--Write-a-python-code-snippet-that-prompts-the-user-to-enter-their-name-and-stores-it-in-a-variable-and-print-a-welcome-message-using-the-entered-name." class="anchor-link">¶</a>
#
# In \[1\]:
#
#     User = str(input ( " Enter your name : "))
#     print ( " Hello innomatics reasearch labs WELCOMES YOU " )
#
#      Enter your name : Pranav Bhawsar
#      Hello innomatics reasearch labs WELCOMES YOU
#
# ## Q2) Create a python program that calculate the area of a rectangle . prompt user to enter the length and width of the recangle, store them in variable the area using the formula (area=length \* width)<a href="#Q2)-Create-a-python-program-that-calculate-the-area-of-a-rectangle-.-prompt-user-to-enter-the-length-and-width-of-the-recangle,-store-them-in-variable-the-area-using-the-formula-(area=length-*-width)" class="anchor-link">¶</a>
#
# In \[2\]:
#
#     print ( " Area of Rectangle = l * w ") # where , l = length of rectangle , w = width of rectangle
#     a =  int(input ( "length :  ")) #length
#     b = int(input ("width = "  )) #width
#     area = a * b
#     print ( ' calculated Area of Rectangle ' , area )
#
#      Area of Rectangle = l * w
#     length :  6
#     width = 4
#      calculated Area of Rectangle  24
#
# ## Q3) Create a python program that calculate the average of three exam scores,prompt user to enter the score, store them in variable,calculate the average,and print the result<a href="#Q3)-Create-a-python-program-that-calculate-the-average-of-three-exam-scores,prompt-user-to-enter-the-score,-store-them-in-variable,calculate-the-average,and-print-the-result" class="anchor-link">¶</a>
#
# In \[3\]:
#
#     x =int(input("user1 : ")) #marks of user 1
#     y =int(input("user2 : ")) #marks of user 2
#     z =int(input("user3 : ")) #marks of user 3
#     print (( x+y+z)/3)
#
#     user1 : 1
#     user2 : 2
#     user3 : 3
#     2.0
#
# ## Q4) Write a python program that converts temperature from celsius to Fahrenheit, prompt user to enter the temperature in celsius, store them in variable, and converts to the Fahrenheit using the formula: Fahrenheit=(celsius \*9/5)+32, and print the converted temperature.<a href="#Q4)-Write-a-python-program-that-converts-temperature-from-celsius-to-Fahrenheit,-prompt-user-to-enter-the-temperature-in-celsius,-store-them-in-variable,-and-converts-to-the-Fahrenheit-using-the-formula:-Fahrenheit=(celsius-*9/5)+32,-and-print-the-converted-temperature." class="anchor-link">¶</a>
#
# In \[4\]:
#
#     print ( " Conversion of temprature from Celsius to fahrenheit : ")
#     x = int(input("Enter the temprature in celsius :  "))
#     print ( " Fahrenheit : " , ( x * 9/5) + 32 )
#
#      Conversion of temprature from Celsius to fahrenheit :
#     Enter the temprature in celsius :  32
#      Fahrenheit :  89.6
#
# ## Q5)what is the logical operators in python and Explain each one with an example<a href="#Q5)what-is-the-logical-operators-in-python-and-Explain-each-one-with-an-example" class="anchor-link">¶</a>
#
# Answer:
#
# -   1\) `and` operator :- when all the arguments are`True` then only
#     output is `True`
#     -   for binary/Boolean -> (follows) Truth Table
#     -   for non-zero -> returns to \`last value
#
# In \[5\]:
#
#     #examples are as follows :- for Binary
#     0 and 1
#
# Out\[5\]:
#
#     0
#
# In \[6\]:
#
#     0 and 0
#
# Out\[6\]:
#
#     0
#
# In \[7\]:
#
#     1 and 0
#
# Out\[7\]:
#
#     0
#
# In \[8\]:
#
#     1 and 1
#
# Out\[8\]:
#
#     1
#
# In \[9\]:
#
#     #for Boolean
#     False and True
#
# Out\[9\]:
#
#     False
#
# In \[10\]:
#
#     False and False
#
# Out\[10\]:
#
#     False
#
# In \[11\]:
#
#     True and False
#
# Out\[11\]:
#
#     False
#
# In \[12\]:
#
#     True and True
#
# Out\[12\]:
#
#     True
#
# In \[13\]:
#
#     #For non-zero
#     10 and 2
#
# Out\[13\]:
#
#     2
#
# In \[14\]:
#
#     2 and 4
#
# Out\[14\]:
#
#     4
#
# In \[15\]:
#
#     2 and 0 #here if one the value is 0/1 then other is considered as 1/0
#
# Out\[15\]:
#
#     0
#
# In \[16\]:
#
#     0 and 3
#
# Out\[16\]:
#
#     0
#
# In \[17\]:
#
#     8 and 9
#
# Out\[17\]:
#
#     9
#
# In \[18\]:
#
#     0.2 and 5 #for non-zero value it returns to last
#
# Out\[18\]:
#
#     5
#
# In \[19\]:
#
#     5.5 and 6.5
#
# Out\[19\]:
#
#     6.5
#
# 2 . `or` operator :-
# `When one of the input is True then it reurns to True`
#
# -   for binary/Boolean -> (follows) Truth Table
# -   for non-zero -> returns to First value
#
# In \[20\]:
#
#     #examples are as follows :- for Binary
#     0 or 0
#
# Out\[20\]:
#
#     0
#
# In \[21\]:
#
#     0 or 1
#
# Out\[21\]:
#
#     1
#
# In \[22\]:
#
#     1 or 0
#
# Out\[22\]:
#
#     1
#
# In \[23\]:
#
#     1 or 1
#
# Out\[23\]:
#
#     1
#
# In \[24\]:
#
#     #for Boolean
#     False or True
#
# Out\[24\]:
#
#     True
#
# In \[25\]:
#
#     False or False
#
# Out\[25\]:
#
#     False
#
# In \[26\]:
#
#     True or False
#
# Out\[26\]:
#
#     True
#
# In \[27\]:
#
#     True or True
#
# Out\[27\]:
#
#     True
#
# In \[28\]:
#
#     #For non-zero
#     10 or 2
#
# Out\[28\]:
#
#     10
#
# In \[29\]:
#
#     1 or 2
#
# Out\[29\]:
#
#     1
#
# In \[30\]:
#
#     2 or 0 #here if one the value is 0/1 then other is considered as 1/0
#
# Out\[30\]:
#
#     2
#
# In \[31\]:
#
#     0 or 2 #here if one the value is 0/1 then other is considered as 1/0
#
# Out\[31\]:
#
#     2
#
# In \[32\]:
#
#     5.5 or 6.5 #for non-zero value it returns to last
#
# Out\[32\]:
#
#     5.5
#
# 3 . `not` operator :-
# `When the input is True/False then it returns to False/True`
#
# -   Always in Boolean
# -   Note:-
# -   0 , 0.0 ,"" is treated as False
#     -   non-zero , non-empty is treated as True
#
# In \[33\]:
#
#     not True
#
# Out\[33\]:
#
#     False
#
# In \[34\]:
#
#     not False
#
# Out\[34\]:
#
#     True
#
# In \[35\]:
#
#     not 100 #here 100 is treated as True
#
# Out\[35\]:
#
#     False
#
# In \[36\]:
#
#     not " "
#
# Out\[36\]:
#
#     False
#
# ## Q6) what ate the Membership operators in python and Explain their usage with examples<a href="#Q6)-what-ate-the-Membership-operators-in-python-and-Explain-their-usage-with-examples" class="anchor-link">¶</a>
#
# Answer :- Membership operators is used to check whether given
# `word , letter , space` is present in the given collection/character .
#
# -   in
# -   not in
#
# In \[37\]:
#
#     "Pranav Bhawsar"
#     "ra" in " Pranav Bhawsar"
#
# Out\[37\]:
#
#     True
#
# In \[38\]:
#
#     "Pranav Bhawsar"
#     " B" in " Pranav Bhawsar" #Note the Space and Case of letter
#
# Out\[38\]:
#
#     True
#
# In \[39\]:
#
#     "Pranav Bhawsar"
#     "ra"  not in " Pranav Bhawsar"
#
# Out\[39\]:
#
#     False
#
# In \[40\]:
#
#     "Pranav Bhawsar"
#     "pranav" not in " Pranav Bhawsar" #note the Case
#
# Out\[40\]:
#
#     True
#
# ## Q7)list and briefly explain the Basic Data types in python<a href="#Q7)list-and-briefly-explain-the-Basic-Data-types--in-python" class="anchor-link">¶</a>
#
# Answer :- Data types in python :-
#
# -   1\) BASIC a) Numerical :-
#
#           + Integer ( ex:- 5)
#           + Float ( ex:- 5.5 )
#           + Complex ( ex:- 5 + 5.5j)
#
#          b) Non - Numerical :-
#           + Boolean ( ex:- True / False )
#           + String ( ex:- " Pranav " )
#
#     2\) COLLECTION / SEQUENTIAL
#
#           + list
#           + tuple
#           + set
#           + Dictionary
#           + Frozen Set
#
# ## Q8)Write a python code snippet that assigns a value to varible and determines its data type using the type() function .<a href="#Q8)Write-a-python-code-snippet-that-assigns-a-value-to-varible-and-determines-its-data-type-using-the-type()-function-." class="anchor-link">¶</a>
#
# In \[41\]:
#
#     l= input( " " )
#     m = int(input ( ))
#     n = float(input( ))
#     print( type (l , m , n ))
#     #we can code that individually and if we run then it will display individually ,
#     #but if we want input from user it is not showing because i think their is  `default value of user input is STRING` .
#
#      pranav
#     7
#     7.7
#
#     ---------------------------------------------------------------------------
#     TypeError                                 Traceback (most recent call last)
#     Cell In[41], line 4
#           2 m = int(input ( ))
#           3 n = float(input( ))
#     ----> 4 print( type (l , m , n ))
#
#     TypeError: type.__new__() argument 2 must be tuple, not int
#
# ##### we can do individual code , as mentioned below.<a href="#we-can-do-individual-code-,-as-mentioned-below." class="anchor-link">¶</a>
#
# In \[42\]:
#
#     a= 2
#     type(a)
#
# Out\[42\]:
#
#     int
#
# In \[43\]:
#
#     b= 5.5
#     type(b)
#
# Out\[43\]:
#
#     float
#
# In \[44\]:
#
#     c= "Pranav is a good guy."
#     type(c)
#
# Out\[44\]:
#
#     str
#
# In \[45\]:
#
#     d=True
#     type(d)
#
# Out\[45\]:
#
#     bool
#
# In \[46\]:
#
#     e=False
#     type(e)
#
# Out\[46\]:
#
#     bool
