# %% [markdown]
# # File opening and assgning the it to new variable<a href="#File-opening-and-assgning-the-it-to-new-variable" class="anchor-link">¶</a>
#
# In \[4\]:
#
#     with open(r"E:\innomatics\class\python\Daily submitting task\correct_it_task7.txt","r") as file:
#         file1=file.read()
#
#     print(file1)
#
#     Python is a compiled language. Before executing Python code, you need to compile it into machine code.
#     Python uses indentation to define blocks of code, making it visually appealing and easy to read.
#     In Python, you must declare variables before using them; otherwise, it will raise an error.
#     Python supports dynamic typing, allowing variables to change their data type during runtime.
#     Python is a statically-typed language, which means you need to declare the data type of variables explicitly.
#     Python is not a cross-platform language, and code written on one operating system may not work on another.
#
# # Correcting the file<a href="#Correcting-the-file" class="anchor-link">¶</a>
#
# In \[8\]:
#
#     file2=file1.replace("compiled" ,"both interpreted and compiled").replace("you need to compile","you need not to compile  ").replace("statically","dynamically").replace("you need to declare","you need not to declare").replace("not a","a")
#
# In \[9\]:
#
#     print(file2)
#
#     Python is a both interpreted and compiled language. Before executing Python code, you need not to compile   it into machine code.
#     Python uses indentation to define blocks of code, making it visually appealing and easy to read.
#     In Python, you must declare variables before using them; otherwise, it will raise an error.
#     Python supports dynamic typing, allowing variables to change their data type during runtime.
#     Python is a dynamically-typed language, which means you need not to declare the data type of variables explicitly.
#     Python is a cross-platform language, and code written on one operating system may not work on another.
#
# # Moving the file from source directory to desired directory<a href="#Moving-the-file-from-source-directory-to-desired-directory" class="anchor-link">¶</a>
#
# In \[3\]:
#
#     import shutil
#     shutil.move(r"E:\innomatics\class\python\Daily submitting task", r"G:\lp")
#
# Out\[3\]:
#
#     'G:\\lp\\Daily submitting task'
