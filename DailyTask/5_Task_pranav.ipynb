# %% [markdown]
# In \[1\]:
#
#     var_name = "innomatics Research labs"
#
# ### Task1<a href="#Task1" class="anchor-link">¶</a>
#
# In \[5\]:
#
#     var_name[0:3]
#
# Out\[5\]:
#
#     'inn'
#
# In \[7\]:
#
#     len(var_name)
#
# Out\[7\]:
#
#     24
#
# In \[10\]:
#
#     var_name[21:24]
#
# Out\[10\]:
#
#     'abs'
#
# In \[12\]:
#
#     var_name[0:24:2]
#
# Out\[12\]:
#
#     'inmtc eerhlb'
#
# In \[14\]:
#
#     var_name[-1:-25:-1]
#
# Out\[14\]:
#
#     'sbal hcraeseR scitamonni'
#
# ### Task2<a href="#Task2" class="anchor-link">¶</a>
#
# In \[18\]:
#
#     x = input("enter the character : ")
#
#     enter the character : Pranav Bhawsar
#
# In \[19\]:
#
#     x
#
# Out\[19\]:
#
#     'Pranav Bhawsar'
#
# In \[20\]:
#
#     x[0]
#
# Out\[20\]:
#
#     'P'
#
# In \[21\]:
#
#     len(x)
#
# Out\[21\]:
#
#     14
#
# In \[22\]:
#
#     x[13]
#
# Out\[22\]:
#
#     'r'
#
# In \[23\]:
#
#     x[2]
#
# Out\[23\]:
#
#     'a'
#
# In \[24\]:
#
#     x[-2]
#
# Out\[24\]:
#
#     'a'
#
# ### Task3<a href="#Task3" class="anchor-link">¶</a>
#
# In \[28\]:
#
#     'I\'m learning python'
#
# Out\[28\]:
#
#     "I'm learning python"
#
# In \[29\]:
#
#     'He said , \"Pyhton is awesome.\"'
#
# Out\[29\]:
#
#     'He said , "Pyhton is awesome."'
