# %% [markdown]
# ### task1<a href="#task1" class="anchor-link">¶</a>
#
# In \[15\]:
#
#     list1= []
#     list1.append(1)
#     list1.append(2)
#     list1.append(3)
#     list1
#
# Out\[15\]:
#
#     [1, 2, 3]
#
# In \[16\]:
#
#     list1.append(4)
#     list1
#
# Out\[16\]:
#
#     [1, 2, 3, 4]
#
# ### task2<a href="#task2" class="anchor-link">¶</a>
#
# In \[18\]:
#
#     x= [ 'Apple' , 'Banana' , 'Orange' , 'Mango' , 'Kiwi']
#     y = [ 'Orange' , 'Mango']   #citrus_fuit
#     z= [ 'Banana' , 'Kiwi']    #Tropical_fruit
#     combined = y+z
#
# In \[19\]:
#
#     combined
#
# Out\[19\]:
#
#     ['Orange', 'Mango', 'Banana', 'Kiwi']
#
# ### task3<a href="#task3" class="anchor-link">¶</a>
#
# In \[26\]:
#
#     clr= [ 'Red' , 'Blue' , 'Red', 'Green' , 'Red']
#
# In \[27\]:
#
#     clr.count('Red')
#
# Out\[27\]:
#
#     3
#
# In \[28\]:
#
#     clr
#
# Out\[28\]:
#
#     ['Red', 'Blue', 'Red', 'Green', 'Red']
#
# In \[29\]:
#
#     clr.pop(2)
#
# Out\[29\]:
#
#     'Red'
#
# In \[31\]:
#
#     clr.pop(3)
#
# Out\[31\]:
#
#     'Red'
#
# In \[33\]:
#
#     clr
#
# Out\[33\]:
#
#     ['Red', 'Blue', 'Green']
#
# ### task4<a href="#task4" class="anchor-link">¶</a>
#
# In \[34\]:
#
#     Groceries = [ 'Bread' , 'Milk' , 'Egg' , 'Butter']
#
# In \[37\]:
#
#     Groceries.append('Cheese')
#
# In \[38\]:
#
#     Groceries
#
# Out\[38\]:
#
#     ['Bread', 'Milk', 'Egg', 'Butter', 'Cheese']
#
# In \[42\]:
#
#     Groceries.pop(1)
#
# Out\[42\]:
#
#     'Milk'
#
# In \[44\]:
#
#     Groceries
#
# Out\[44\]:
#
#     ['Bread', 'Butter', 'Cheese']
#
# In \[47\]:
#
#     Groceries.insert(1,'Yogurt')
#
# In \[48\]:
#
#     Groceries
#
# Out\[48\]:
#
#     ['Bread', 'Yogurt', 'Butter', 'Cheese']
