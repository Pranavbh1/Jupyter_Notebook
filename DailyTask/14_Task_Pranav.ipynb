# %% [markdown]
# # Task 1 :FUNCTION PARAMETER<a href="#Task-1-:FUNCTION-PARAMETER" class="anchor-link">¶</a>
#
# ##### 1.Create a python function called "Calculate_Area" that takes two parameters i.e. length and breadth<a href="#1.Create-a-python-function-called-%22Calculate_Area%22-that-takes-two-parameters-i.e.-length-and-breadth" class="anchor-link">¶</a>
#
# -   inside the function , calculate the area of a rectangle using the
#     formula : area=length\*breadth .
# -   return the calculated area from the function.
# -   Prompt the user to enter the length and width of a rectangle .
# -   Call the "Calculate_area" functions with the user's input as
#     arguments and display the calculated area.
#
# In \[3\]:
#
#     length=int(input("l: "))
#     breadth=int(input("b: "))
#     def Calculate_Area(length , breadth):
#         print(length*breadth)
#
#     Calculate_Area(5,6)
#
#     l: 5
#     b: 6
#     30
#
# # TASK2:-VARIABLES AND SCOPE<a href="#TASK2:-VARIABLES-AND-SCOPE" class="anchor-link">¶</a>
#
# -   Create a Python program that performs the following tasks:
#
# -   Define a global variable called "count" and initialize it with a
#     value of 0.
#
# -   Write a function called "increment_count" that increments the value
#     of the "count" variable by 1.
#
# -   Call the "increment_count function three times.
#
# -   Display the final value of the "count" variable.
#
# In \[4\]:
#
#     count = [0]
#     def increament_count(x):
#         x+=1
#         print(x)
#
# In \[5\]:
#
#     increament_count(5)
#
#     6
#
# In \[6\]:
#
#     increament_count(99)
#
#     100
#
# In \[7\]:
#
#     increament_count(1099)
#
#     1100
#
# # \# TASK3:- LAMBDA FUNCTION<a href="#%23-TASK3:--LAMBDA-FUNCTION" class="anchor-link">¶</a>
#
# -   Create a lambda function called "multiply_numbers" that takes two
#     parameters: num1 and num2.
#
# -   Inside the lambda function, multiply the two numbers and return the
#     result.
#
# -   Prompt the user to enter two numbers.
#
# -   Call the lambda function with the user's Inputs as arguments and
#     display the result.
#
# In \[10\]:
#
#     Multiply_numbers = lambda x,y : x*y
#     x=int(input("enter the first value: "))
#     y=int(input("enter the second value: "))
#     Multiply_numbers(x,y)
#
#     enter the first value: 5
#     enter the second value: 6
#
# Out\[10\]:
#
#     30
