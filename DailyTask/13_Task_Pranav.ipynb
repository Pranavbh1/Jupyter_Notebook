# %% [markdown]
# # Tasks:<a href="#Tasks:" class="anchor-link">¶</a>
#
# ##### 1.Write a function called "add numbers" takes two integer as input and returns as sum .<a href="#1.Write-a-function-called-%22add-numbers%22-takes-two-integer-as-input-and-returns-as-sum-." class="anchor-link">¶</a>
#
# In \[1\]:
#
#     def add(a,b):
#         print(a+b)
#
# In \[3\]:
#
#     a=int(input("enter the value of first integer: "))
#     b=int(input("enter the value of `second` integer: "))
#     add(a,b)
#
#     enter the value of first integer: 5
#     enter the value of `second` integer: 6
#     11
#
# ##### 2.Write a function called "Multiply" takes two integer as input and returns as multiplication.<a href="#2.Write-a-function-called-%22Multiply%22-takes-two-integer-as-input-and-returns-as-multiplication." class="anchor-link">¶</a>
#
# In \[10\]:
#
#     def mul(x,y):
#         print(x*y)
#     x=int(input("enter the value of first integer: "))
#     y=int(input("enter the value of second integer: "))
#     mul(x,y)
#
#     enter the value of first integer: 5
#     enter the value of second integer: 6
#     30
#
# ##### 3.Write a function called "AVERAGE" takes list of integers as input and returns as AVERAGE.<a href="#3.Write-a-function-called-%22AVERAGE%22-takes-list-of-integers-as-input-and-returns-as-AVERAGE." class="anchor-link">¶</a>
#
# In \[35\]:
#
#     def avg(x):
#         print(sum(x)/len(x))
#
#     x = [1,50]
#     avg(x)
#
#
#     25.5
#
# ##### 4.Write a function called "is_even" that takes an integer as a input and returns True if the numbers is even, and False otherwise<a href="#4.Write-a-function-called-%22is_even%22-that-takes-an-integer-as-a-input-and-returns-True-if-the-numbers-is-even,-and-False-otherwise" class="anchor-link">¶</a>
#
# In \[40\]:
#
#     def iseven(v):
#         if v%2==0:
#             print("True")
#         else:
#             print("False")
#
# In \[41\]:
#
#     iseven(78)
#
#     True
#
# In \[42\]:
#
#     iseven(79)
#
#     False
#
# ##### 5.Write a function called "is_prime" that takes an integer as input and returns True if the number is prime, and False otherwise.<a href="#5.Write-a-function-called-%22is_prime%22-that-takes-an-integer-as-input-and-returns-True-if-the-number-is-prime,-and-False-otherwise." class="anchor-link">¶</a>
#
# In \[50\]:
#
#     def is_prime(n):
#         if n<0:
#             print("Can't evaluate" )
#         elif n <=1:
#             return False
#         else:
#             for i in range(2,n):
#                 if n%i==0:
#                     print(False)
#                     break
#             else:
#                 print(True)
#
# In \[51\]:
#
#     is_prime(19)
#
#     True
#
# In \[52\]:
#
#     is_prime(20)
#
#     False
#
# In \[53\]:
#
#     is_prime(21)
#
#     False
#
# In \[54\]:
#
#     is_prime(22)
#
#     False
#
# In \[55\]:
#
#     is_prime(23)
#
#     True
#
# In \[56\]:
#
#     is_prime(24)
#
#     False
#
# In \[57\]:
#
#     is_prime(5)
#
#     True
#
# In \[58\]:
#
#     is_prime(4)
#
#     False
#
# In \[59\]:
#
#     is_prime(6)
#
#     False
#
# In \[47\]:
#
#     is_prime(7)
#
#     True
#
# In \[60\]:
#
#     is_prime(49466)
#
#     False
#
# In \[62\]:
#
#     is_prime(9)
#
#     False
#
# In \[63\]:
#
#     is_prime(0)
#
# Out\[63\]:
#
#     False
#
# In \[64\]:
#
#     is_prime(-1)
#
#     Can't evaluate
#
# ##### 6.Write a function called "reverse_string" that takes a string as input and returns the reverse of that string<a href="#6.Write-a-function-called-%22reverse_string%22-that-takes-a-string-as-input-and-returns-the-reverse-of-that-string" class="anchor-link">¶</a>
#
# In \[89\]:
#
#     def reverse_string(a):
#         print(a)
#
# In \[95\]:
#
#     a=str(input("enter a string: "))
#     print(a[::-1])
#
#     enter a string: pranav
#     vanarp
#
# ##### 7.Write a function called "count_vowels" that takes a string as input and returns the number of vowels(a,e,i,o,u) in that string<a href="#7.Write-a-function-called-%22count_vowels%22-that-takes-a-string-as-input-and-returns-the-number-of-vowels(a,e,i,o,u)-in-that-string" class="anchor-link">¶</a>
#
# In \[49\]:
#
#     def count_vowels(b):
#         vowel=['a','e','i','o','u','A','E','I','O','U']
#         a = 0
#         for i in b :
#             if i in vowel:
#                 a = a+1
#         print(a)
#
# In \[56\]:
#
#     count_vowels('Hello world , This is Innomatics research labs')
#
#     13
#
# In \[55\]:
#
#     def count_vowels(b):
#         vowel=['a','e','i','o','u','A','E','I','O','U']
#         a = []
#         for i in b :
#             if i in vowel:
#                 a.append(i)
#         print(len(a))
#
# ##### 8.Write a function called "find_max" that takes a list of numbers as input and returns the maximum value in that list.<a href="#8.Write-a-function-called-%22find_max%22-that-takes-a-list-of-numbers-as-input-and-returns-the-maximum-value-in-that-list." class="anchor-link">¶</a>
#
# In \[98\]:
#
#     def find_max(b):
#
#         for e in b:
#             pass
#         print(max(b))
#
# In \[101\]:
#
#     find_max([1,2,3,4,5,6,99,101,10,55,66,117])
#
#     117
#
# ##### 9.Write a function called "find_min" that takes a list of numbers as input and returns the minimum value in that list.<a href="#9.Write-a-function-called-%22find_min%22-that-takes-a-list-of-numbers-as-input-and-returns-the-minimum-value-in-that-list." class="anchor-link">¶</a>
#
# In \[102\]:
#
#     def find_min(b):
#
#         for e in b:
#             pass
#         print(min(b))
#
# In \[103\]:
#
#     find_min([1,2,3,4,5,6,99,101,10,55,66,117])
#
#     1
