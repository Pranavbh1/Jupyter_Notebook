# %% [markdown]
# # String Manipulation and Flow Control<a href="#String-Manipulation-and-Flow-Control" class="anchor-link">¶</a>
#
# ##### a) Write a program that prompts the user to enter a sentence. The program should reverse the words in the sentence while preserving the word order.<a href="#a)-Write-a-program-that-prompts-the-user-to-enter-a-sentence.-The-program-should-reverse-the-words-in-the-sentence-while-preserving-the-word-order." class="anchor-link">¶</a>
#
# In \[2\]:
#
#     a= str(input("  "))
#     b=a.split()
#     for i in range(0,len(b)):
#         print(b[::-1])
#         break
#
#       Pranav is good guy
#     ['guy', 'good', 'is', 'Pranav']
#
# In \[3\]:
#
#     a= str(input("  "))
#     for i in range(0,len(a)):
#         print(a[::-1])
#         break
#
#       Pranav is good guy
#     yug doog si vanarP
#
# ##### b) Create a program that takes a string as input and checks if it is a valid email address based on specific criteria (e.g., presence of @ symbol and valid domain name)<a href="#b)-Create-a-program-that-takes-a-string-as-input-and-checks-if-it-is-a-valid-email-address-based-on-specific-criteria-(e.g.,-presence-of-@-symbol-and-valid-domain-name)" class="anchor-link">¶</a>
#
# In \[6\]:
#
#     mail=str(input("Enter your mail ID :  "))
#     if mail.find("@" and ".com"):
#         print("It is a valid email address")
#     else :
#         ("It is not valid")
#
#     Enter your mail ID :  pb@gmail.com
#     It is a valid email address
#
# # Data Structures and Control Flow<a href="#Data-Structures-and-Control-Flow" class="anchor-link">¶</a>
#
# ##### a) write a program that implements a simple contact book. The program should allow users to add contacts, search for contacts by name, and display all contacts.<a href="#a)-write-a-program-that-implements-a-simple-contact-book.-The-program-should-allow-users-to-add-contacts,-search-for-contacts-by-name,-and-display-all-contacts." class="anchor-link">¶</a>
#
# In \[6\]:
#
#     contact_book={"Kirti":888399000,"Chaitnya":9074000000,"Pawan":7770870000}
#     user_choice=input("Add/Search/Display:")
#     if user_choice=="Add":
#         name=input("Enter name: ")
#         number=int(input("Enter number: "))
#         contact_book.update({name:number})
#         print(contact_book)
#     elif user_choice=="Search":
#         user_name=input("Enter name to  be searched :")
#         search=contact_book.get(user_name)
#         print(search)
#     elif user_choice=="Display":
#         print(contact_book)
#
#     Add/Search/Display:Display
#     {'Kirti': 888399000, 'Chaitnya': 9074000000, 'Pawan': 7770870000}
#
# ##### b) Create a program that simulates a basic inventory management system using dictionaries. The program should allow users to add items, remove items, and display the current inventory.<a href="#b)-Create-a-program-that-simulates-a-basic-inventory-management-system-using-dictionaries.-The-program-should-allow-users-to-add-items,-remove-items,-and-display-the-current-inventory." class="anchor-link">¶</a>
#
# In \[9\]:
#
#     inv_sys={"Metal":"Bottleopener","Plastic":"Cellphone","Silicon":"IC"}
#     user=input("Enter your choice: ")
#     if user=="add":
#         item=input("Enter new substance: ")
#         brand=input("Enter entity: ")
#         inv_sys.update({item:brand})
#         print(inv_sys)
#     elif user=="remove":
#         remove=input("Enter item to remove: ")
#         inv_sys.pop(remove)
#         print(inv_sys)
#     elif user=="display":
#         print(inv_sys)
#     else:
#         print("Invalid choice")
#
#
#     Enter your choice: remove
#     Enter item to remove: Plastic
#     {'Metal': 'Bottleopener', 'Silicon': 'IC'}
