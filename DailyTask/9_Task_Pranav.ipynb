# %% [markdown]
# ### Task 1 :- Leap year checking<a href="#Task-1-:--Leap-year-checking" class="anchor-link">¶</a>
#
# In \[3\]:
#
#     #Leap year checker
#     year = int ( input ( " Enter the year :  " ) )
#     if year%4 and year%400 :
#         print ( " Selected year is a leap year " )
#     else:
#         print ( " Selected year is not a leap year " )
#
#      Enter the year :  2056
#      Selected year is not a leap year
#
# ### Task 2 :- Grade Calculator<a href="#Task-2-:--Grade-Calculator" class="anchor-link">¶</a>
#
# In \[1\]:
#
#     score = int ( input ( "enter the score of student :  " ) )
#     if score>=90 and score<=100 :
#         print ( ' A ' )
#     elif score>=80 and score<=89:
#         print ( " B " )
#     elif score>=70 and score<=79:
#         print ( " C " )
#     elif score>=60 and score<=69 :
#         print ( " D " )
#     else :
#         print ( " F " )
#
#     enter the score of student :  99
#      A
#
# ### Task 3 :- Calculator<a href="#Task-3-:--Calculator" class="anchor-link">¶</a>
#
# In \[4\]:
#
#     a = int ( input ( " enter the number a : " ) )
#     b = int ( input ( " enter the number b : " ) )
#     c = input ( " enter the operation : " )
#     if c=='+' :
#         print (a+b)
#     elif c=='-' :
#         print ( a-b)
#     elif c=="*" :
#         print (a*b)
#     elif c=="/" :
#         print (a/b)
#     else :
#         print ("enter a valid operation")
#
#      enter the number a : 5
#      enter the number b : 6
#      enter the operation : //
#     enter a valid operation
