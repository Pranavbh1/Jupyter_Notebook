# %% [markdown]
# ### Task1<a href="#Task1" class="anchor-link">¶</a>
#
# In \[1\]:
#
#     Fruits = ( 'Apple' , 'Banana' , 'Orange', 'Mango' , 'Kiwi')
#
# In \[2\]:
#
#     Fruits
#
# Out\[2\]:
#
#     ('Apple', 'Banana', 'Orange', 'Mango', 'Kiwi')
#
# In \[3\]:
#
#     len(Fruits)
#
# Out\[3\]:
#
#     5
#
# In \[8\]:
#
#     Fruits[2]
#
# Out\[8\]:
#
#     'Orange'
#
# In \[9\]:
#
#     Fruits[1:6]
#
# Out\[9\]:
#
#     ('Banana', 'Orange', 'Mango', 'Kiwi')
#
# In \[10\]:
#
#     more_Fruits = ( 'Grape' 'Pear' , 'Pineapple')
#
# In \[11\]:
#
#     All_fruits= Fruits+more_Fruits
#
# In \[12\]:
#
#     All_fruits
#
# Out\[12\]:
#
#     ('Apple', 'Banana', 'Orange', 'Mango', 'Kiwi', 'GrapePear', 'Pineapple')
#
# In \[13\]:
#
#     'Kiwi' in All_fruits
#
# Out\[13\]:
#
#     True
#
# In \[14\]:
#
#     All_fruits.count('Banana')
#
# Out\[14\]:
#
#     1
#
# ### Task2<a href="#Task2" class="anchor-link">¶</a>
#
# In \[25\]:
#
#     Countries= { 'USA' , 'Canada' , 'Mexico' , "Brazil" , 'India'}
#
# In \[26\]:
#
#     Countries
#
# Out\[26\]:
#
#     {'Brazil', 'Canada', 'India', 'Mexico', 'USA'}
#
# In \[27\]:
#
#     Countries.add("China")
#
# In \[28\]:
#
#     Countries.add('Germany')
#
# In \[29\]:
#
#     Countries
#
# Out\[29\]:
#
#     {'Brazil', 'Canada', 'China', 'Germany', 'India', 'Mexico', 'USA'}
#
# In \[30\]:
#
#     European_Countries = { 'Germany' , 'France' , 'Spain' , 'Italy' , 'United kingdom'}
#
# In \[31\]:
#
#     European_Countries
#
# Out\[31\]:
#
#     {'France', 'Germany', 'Italy', 'Spain', 'United kingdom'}
#
# In \[32\]:
#
#     Countries.intersection(European_Countries)
#
# Out\[32\]:
#
#     {'Germany'}
#
# In \[33\]:
#
#     Countries.union(European_Countries)
#
# Out\[33\]:
#
#     {'Brazil',
#      'Canada',
#      'China',
#      'France',
#      'Germany',
#      'India',
#      'Italy',
#      'Mexico',
#      'Spain',
#      'USA',
#      'United kingdom'}
#
# In \[36\]:
#
#     Countries.remove('India')
#
# In \[37\]:
#
#     Countries
#
# Out\[37\]:
#
#     {'Brazil', 'Canada', 'China', 'Germany', 'Mexico', 'USA'}
