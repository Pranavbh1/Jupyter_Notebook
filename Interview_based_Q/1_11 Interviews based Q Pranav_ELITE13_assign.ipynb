# %% [markdown]
# ####\# 1) Given the following code snippet, edit the code such that it
# generates a list sorted in descending order: num = \[5,1,3,4,6,2\] n =
# len(num) min =0 pos = 0 for i in range(n): print("Before: ",num) min =
# num\[i\] pos = i for j in range(i+1,n): if num\[j\]
#
# In \[3\]:
#
#     num = [5,1,3,4,6,2]
#     n = len(num)
#     max =0
#     pos = 0
#     for i in range(n):
#       print("Before: ",num)
#       max = num[i]
#       pos = i
#       for j in range(i+1,n):
#         if num[j]>max:
#           max = num[j]
#           pos = j
#       temp = num[i]
#       num[i] = max
#       num[pos] = temp
#       print("After : ",num)
#       print()
#
#     # print(num)
#
#     Before:  [5, 1, 3, 4, 6, 2]
#     After :  [6, 1, 3, 4, 5, 2]
#
#     Before:  [6, 1, 3, 4, 5, 2]
#     After :  [6, 5, 3, 4, 1, 2]
#
#     Before:  [6, 5, 3, 4, 1, 2]
#     After :  [6, 5, 4, 3, 1, 2]
#
#     Before:  [6, 5, 4, 3, 1, 2]
#     After :  [6, 5, 4, 3, 1, 2]
#
#     Before:  [6, 5, 4, 3, 1, 2]
#     After :  [6, 5, 4, 3, 2, 1]
#
#     Before:  [6, 5, 4, 3, 2, 1]
#     After :  [6, 5, 4, 3, 2, 1]
#
# ##### 2) Given 3 numbers as input, come up with unique methods using which the 3 numbers can<a href="#2)-Given-3-numbers-as-input,-come-up-with-unique-methods-using-which-the-3-numbers-can" class="anchor-link">¶</a>
#
# be swapped.
#
# In \[8\]:
#
#     a,b,c = 11,22,33
#     a = a + b + c
#     b = a - (b+c)
#     c = a - (b+c)
#     a = a - (b+c)
#     print(a,b,c)
#
#     33 11 22
